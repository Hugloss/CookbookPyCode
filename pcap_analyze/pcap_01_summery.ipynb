# %%
# !pip install scapy

# %% [markdown]
# # Basic details of each packet

# %% [markdown]
# - https://challenge.fra.se/

# %%
from scapy.all import rdpcap

# %%
filename = 'challenges/challenge/challenge.pcap'
filename = 'challenges/challenge/analytikertestet.pcap'
filename = 'challenges/challenge/trafik.pcap'

# %%
# Load the pcap file
packets = rdpcap(filename)

# Analyze each packet
for packet in packets:
    # Print basic packet details
    print(packet.summary())
# Out:
# Ether / IP / TCP 172.23.0.3:46642 > 172.23.0.2:imap2 S
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46642 SA
# Ether / IP / TCP 172.23.0.3:46642 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46642 PA / Raw
# Ether / IP / TCP 172.23.0.3:46642 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.3:46642 > 172.23.0.2:imap2 PA / Raw
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46642 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46642 PA / Raw
# Ether / IP / TCP 172.23.0.3:46642 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.3:46642 > 172.23.0.2:imap2 PA / Raw
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46642 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46642 PA / Raw
# Ether / IP / TCP 172.23.0.3:46642 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 S
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 SA
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.3:46642 > 172.23.0.2:imap2 PA / Raw
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46642 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46642 PA / Raw
# Ether / IP / TCP 172.23.0.3:46642 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 PA / Raw
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.3:46642 > 172.23.0.2:imap2 PA / Raw
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46642 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46642 PA / Raw
# Ether / IP / TCP 172.23.0.3:46642 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.3:46642 > 172.23.0.2:imap2 PA / Raw
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46642 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46642 PA / Raw
# Ether / IP / TCP 172.23.0.3:46642 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.3:46642 > 172.23.0.2:imap2 PA / Raw
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46642 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46642 PA / Raw
# Ether / IP / TCP 172.23.0.3:46642 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 PA / Raw
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 PA / Raw
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 PA / Raw
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 PA / Raw
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 PA / Raw
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 PA / Raw
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.3:46642 > 172.23.0.2:imap2 PA / Raw
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46642 A
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 PA / Raw
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46642 PA / Raw
# Ether / IP / TCP 172.23.0.3:46642 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 PA / Raw
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 PA / Raw
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 PA / Raw
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 PA / Raw
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 PA / Raw
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 PA / Raw
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 PA / Raw
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 PA / Raw
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 PA / Raw
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 PA / Raw
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 PA / Raw
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 PA / Raw
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 PA / Raw
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 PA / Raw
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 PA / Raw
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 PA / Raw
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 A / Raw
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 PA / Raw
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.3:43650 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:43650 SA
# Ether / IP / TCP 172.23.0.3:43650 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:43650 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:43650 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:43650 PA / Raw
# Ether / IP / TCP 172.23.0.3:43650 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:43650 PA / Raw
# Ether / IP / TCP 172.23.0.3:43650 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:43650 FA
# Ether / IP / TCP 172.23.0.3:43650 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:43650 A
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 PA / Raw
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 PA / Raw
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 PA / Raw
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 PA / Raw
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.3:51384 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:51384 SA
# Ether / IP / TCP 172.23.0.3:51384 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:51384 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:51384 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:51384 PA / Raw
# Ether / IP / TCP 172.23.0.3:51384 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:51384 PA / Raw
# Ether / IP / TCP 172.23.0.3:51384 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:51384 FA
# Ether / IP / TCP 172.23.0.3:51384 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:51384 A
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 PA / Raw
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 PA / Raw
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 PA / Raw
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 PA / Raw
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 PA / Raw
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 PA / Raw
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 PA / Raw
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 PA / Raw
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.3:46642 > 172.23.0.2:imap2 PA / Raw
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46642 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46642 PA / Raw
# Ether / IP / TCP 172.23.0.3:46642 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46642 FA
# Ether / IP / TCP 172.23.0.3:46642 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.3:46642 > 172.23.0.2:imap2 FA
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46642 A
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 PA / Raw
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 A
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 PA / Raw
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 FA
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 A
# Ether / IP / TCP 172.23.0.3:46652 > 172.23.0.2:imap2 FA
# Ether / IP / TCP 172.23.0.2:imap2 > 172.23.0.3:46652 A
# Ether / IP / TCP 172.23.0.3:32876 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:32876 SA
# Ether / IP / TCP 172.23.0.3:32876 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:32876 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:32876 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:32876 PA / Raw
# Ether / IP / TCP 172.23.0.3:32876 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:32876 PA / Raw
# Ether / IP / TCP 172.23.0.3:32876 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:32876 FA
# Ether / IP / TCP 172.23.0.3:32876 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:32876 A
# Ether / IP / TCP 172.23.0.3:39996 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:39996 SA
# Ether / IP / TCP 172.23.0.3:39996 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:39996 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:39996 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:39996 PA / Raw
# Ether / IP / TCP 172.23.0.3:39996 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:39996 PA / Raw
# Ether / IP / TCP 172.23.0.3:39996 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:39996 FA
# Ether / IP / TCP 172.23.0.3:39996 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:39996 A
# Ether / IP / TCP 172.23.0.3:40000 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:40000 SA
# Ether / IP / TCP 172.23.0.3:40000 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:40000 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:40000 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:40000 PA / Raw
# Ether / IP / TCP 172.23.0.3:40000 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:40000 PA / Raw
# Ether / IP / TCP 172.23.0.3:40000 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:40000 FA
# Ether / IP / TCP 172.23.0.3:40000 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:40000 A
# Ether / IP / TCP 172.23.0.3:40006 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:40006 SA
# Ether / IP / TCP 172.23.0.3:40006 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:40006 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:40006 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:40006 PA / Raw
# Ether / IP / TCP 172.23.0.3:40006 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:40006 PA / Raw
# Ether / IP / TCP 172.23.0.3:40006 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:40006 FA
# Ether / IP / TCP 172.23.0.3:40006 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:40006 A
# Ether / IP / TCP 172.23.0.3:54440 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:54440 SA
# Ether / IP / TCP 172.23.0.3:54440 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:54440 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:54440 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:54440 PA / Raw
# Ether / IP / TCP 172.23.0.3:54440 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:54440 PA / Raw
# Ether / IP / TCP 172.23.0.3:54440 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:54440 FA
# Ether / IP / TCP 172.23.0.3:54440 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:54440 A
# Ether / IP / TCP 172.23.0.3:54456 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:54456 SA
# Ether / IP / TCP 172.23.0.3:54456 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:54456 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:54456 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:54456 PA / Raw
# Ether / IP / TCP 172.23.0.3:54456 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:54456 PA / Raw
# Ether / IP / TCP 172.23.0.3:54456 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:54456 FA
# Ether / IP / TCP 172.23.0.3:54456 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:54456 A
# Ether / IP / TCP 172.23.0.3:54468 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:54468 SA
# Ether / IP / TCP 172.23.0.3:54468 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:54468 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:54468 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:54468 PA / Raw
# Ether / IP / TCP 172.23.0.3:54468 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:54468 PA / Raw
# Ether / IP / TCP 172.23.0.3:54468 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:54468 FA
# Ether / IP / TCP 172.23.0.3:54468 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:54468 A
# Ether / IP / TCP 172.23.0.3:54480 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:54480 SA
# Ether / IP / TCP 172.23.0.3:54480 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:54480 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:54480 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:54480 PA / Raw
# Ether / IP / TCP 172.23.0.3:54480 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:54480 PA / Raw
# Ether / IP / TCP 172.23.0.3:54480 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:54480 FA
# Ether / IP / TCP 172.23.0.3:54480 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:54480 A
# Ether / IP / TCP 172.23.0.3:51630 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:51630 SA
# Ether / IP / TCP 172.23.0.3:51630 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:51630 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:51630 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:51630 PA / Raw
# Ether / IP / TCP 172.23.0.3:51630 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:51630 PA / Raw
# Ether / IP / TCP 172.23.0.3:51630 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:51630 FA
# Ether / IP / TCP 172.23.0.3:51630 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:51630 A
# Ether / IP / TCP 172.23.0.3:51640 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:51640 SA
# Ether / IP / TCP 172.23.0.3:51640 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:51640 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:51640 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:51640 PA / Raw
# Ether / IP / TCP 172.23.0.3:51640 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:51640 PA / Raw
# Ether / IP / TCP 172.23.0.3:51640 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:51640 FA
# Ether / IP / TCP 172.23.0.3:51640 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:51640 A
# Ether / IP / TCP 172.23.0.3:51648 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:51648 SA
# Ether / IP / TCP 172.23.0.3:51648 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:51648 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:51648 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:51648 PA / Raw
# Ether / IP / TCP 172.23.0.3:51648 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:51648 PA / Raw
# Ether / IP / TCP 172.23.0.3:51648 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:51648 FA
# Ether / IP / TCP 172.23.0.3:51648 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:51648 A
# Ether / IP / TCP 172.23.0.3:58300 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58300 SA
# Ether / IP / TCP 172.23.0.3:58300 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:58300 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58300 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58300 PA / Raw
# Ether / IP / TCP 172.23.0.3:58300 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58300 PA / Raw
# Ether / IP / TCP 172.23.0.3:58300 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58300 FA
# Ether / IP / TCP 172.23.0.3:58300 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58300 A
# Ether / IP / TCP 172.23.0.3:58302 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58302 SA
# Ether / IP / TCP 172.23.0.3:58302 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:58302 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58302 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58302 PA / Raw
# Ether / IP / TCP 172.23.0.3:58302 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58302 PA / Raw
# Ether / IP / TCP 172.23.0.3:58302 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58302 FA
# Ether / IP / TCP 172.23.0.3:58302 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58302 A
# Ether / IP / TCP 172.23.0.3:58304 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58304 SA
# Ether / IP / TCP 172.23.0.3:58304 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:58304 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58304 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58304 PA / Raw
# Ether / IP / TCP 172.23.0.3:58304 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58304 PA / Raw
# Ether / IP / TCP 172.23.0.3:58304 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58304 FA
# Ether / IP / TCP 172.23.0.3:58304 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58304 A
# Ether / IP / TCP 172.23.0.3:58310 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58310 SA
# Ether / IP / TCP 172.23.0.3:58310 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:58310 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58310 A
# Ether / IP / TCP 172.23.0.3:58310 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58310 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58310 PA / Raw
# Ether / IP / TCP 172.23.0.3:58310 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58310 PA / Raw
# Ether / IP / TCP 172.23.0.3:58310 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58310 FA
# Ether / IP / TCP 172.23.0.3:58310 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58310 A
# Ether / IP / TCP 172.23.0.3:58318 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58318 SA
# Ether / IP / TCP 172.23.0.3:58318 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:58318 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58318 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58318 PA / Raw
# Ether / IP / TCP 172.23.0.3:58318 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58318 PA / Raw
# Ether / IP / TCP 172.23.0.3:58318 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58318 FA
# Ether / IP / TCP 172.23.0.3:58318 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58318 A
# Ether / IP / TCP 172.23.0.3:48096 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48096 SA
# Ether / IP / TCP 172.23.0.3:48096 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:48096 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48096 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48096 PA / Raw
# Ether / IP / TCP 172.23.0.3:48096 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48096 PA / Raw
# Ether / IP / TCP 172.23.0.3:48096 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48096 FA
# Ether / IP / TCP 172.23.0.3:48096 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48096 A
# Ether / IP / TCP 172.23.0.3:48106 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48106 SA
# Ether / IP / TCP 172.23.0.3:48106 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:48106 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48106 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48106 PA / Raw
# Ether / IP / TCP 172.23.0.3:48106 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48106 PA / Raw
# Ether / IP / TCP 172.23.0.3:48106 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48106 FA
# Ether / IP / TCP 172.23.0.3:48106 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48106 A
# Ether / IP / TCP 172.23.0.3:48118 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48118 SA
# Ether / IP / TCP 172.23.0.3:48118 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:48118 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48118 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48118 PA / Raw
# Ether / IP / TCP 172.23.0.3:48118 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48118 PA / Raw
# Ether / IP / TCP 172.23.0.3:48118 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48118 FA
# Ether / IP / TCP 172.23.0.3:48118 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48118 A
# Ether / IP / TCP 172.23.0.3:48134 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48134 SA
# Ether / IP / TCP 172.23.0.3:48134 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:48134 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48134 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48134 PA / Raw
# Ether / IP / TCP 172.23.0.3:48134 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48134 PA / Raw
# Ether / IP / TCP 172.23.0.3:48134 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48134 FA
# Ether / IP / TCP 172.23.0.3:48134 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48134 A
# Ether / IP / TCP 172.23.0.3:48138 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48138 SA
# Ether / IP / TCP 172.23.0.3:48138 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:48138 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48138 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48138 PA / Raw
# Ether / IP / TCP 172.23.0.3:48138 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48138 PA / Raw
# Ether / IP / TCP 172.23.0.3:48138 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48138 FA
# Ether / IP / TCP 172.23.0.3:48138 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48138 A
# Ether / IP / TCP 172.23.0.3:48146 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48146 SA
# Ether / IP / TCP 172.23.0.3:48146 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:48146 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48146 A
# Ether / IP / TCP 172.23.0.3:48146 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48146 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48146 PA / Raw
# Ether / IP / TCP 172.23.0.3:48146 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48146 PA / Raw
# Ether / IP / TCP 172.23.0.3:48146 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48146 FA
# Ether / IP / TCP 172.23.0.3:48146 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48146 A
# Ether / IP / TCP 172.23.0.3:48154 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48154 SA
# Ether / IP / TCP 172.23.0.3:48154 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:48154 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48154 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48154 PA / Raw
# Ether / IP / TCP 172.23.0.3:48154 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48154 PA / Raw
# Ether / IP / TCP 172.23.0.3:48154 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48154 FA
# Ether / IP / TCP 172.23.0.3:48154 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:48154 A
# Ether / IP / TCP 172.23.0.3:58778 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58778 SA
# Ether / IP / TCP 172.23.0.3:58778 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:58778 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58778 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58778 PA / Raw
# Ether / IP / TCP 172.23.0.3:58778 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58778 PA / Raw
# Ether / IP / TCP 172.23.0.3:58778 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58778 FA
# Ether / IP / TCP 172.23.0.3:58778 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58778 A
# Ether / IP / TCP 172.23.0.3:58782 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58782 SA
# Ether / IP / TCP 172.23.0.3:58782 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:58782 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58782 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58782 PA / Raw
# Ether / IP / TCP 172.23.0.3:58782 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58782 PA / Raw
# Ether / IP / TCP 172.23.0.3:58782 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58782 FA
# Ether / IP / TCP 172.23.0.3:58782 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58782 A
# Ether / IP / TCP 172.23.0.3:58794 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58794 SA
# Ether / IP / TCP 172.23.0.3:58794 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:58794 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58794 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58794 PA / Raw
# Ether / IP / TCP 172.23.0.3:58794 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58794 PA / Raw
# Ether / IP / TCP 172.23.0.3:58794 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58794 FA
# Ether / IP / TCP 172.23.0.3:58794 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:58794 A
# Ether / IP / TCP 172.23.0.3:57248 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57248 SA
# Ether / IP / TCP 172.23.0.3:57248 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:57248 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57248 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57248 PA / Raw
# Ether / IP / TCP 172.23.0.3:57248 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57248 PA / Raw
# Ether / IP / TCP 172.23.0.3:57248 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57248 FA
# Ether / IP / TCP 172.23.0.3:57248 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57248 A
# Ether / IP / TCP 172.23.0.3:57258 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57258 SA
# Ether / IP / TCP 172.23.0.3:57258 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:57258 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57258 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57258 PA / Raw
# Ether / IP / TCP 172.23.0.3:57258 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57258 PA / Raw
# Ether / IP / TCP 172.23.0.3:57258 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57258 FA
# Ether / IP / TCP 172.23.0.3:57258 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57258 A
# Ether / IP / TCP 172.23.0.3:57260 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57260 SA
# Ether / IP / TCP 172.23.0.3:57260 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:57260 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57260 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57260 PA / Raw
# Ether / IP / TCP 172.23.0.3:57260 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57260 PA / Raw
# Ether / IP / TCP 172.23.0.3:57260 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57260 FA
# Ether / IP / TCP 172.23.0.3:57260 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57260 A
# Ether / IP / TCP 172.23.0.3:57276 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57276 SA
# Ether / IP / TCP 172.23.0.3:57276 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:57276 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57276 A
# Ether / IP / TCP 172.23.0.3:57276 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57276 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57276 PA / Raw
# Ether / IP / TCP 172.23.0.3:57276 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57276 PA / Raw
# Ether / IP / TCP 172.23.0.3:57276 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57276 FA
# Ether / IP / TCP 172.23.0.3:57276 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57276 A
# Ether / IP / TCP 172.23.0.3:57284 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57284 SA
# Ether / IP / TCP 172.23.0.3:57284 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:57284 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57284 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57284 PA / Raw
# Ether / IP / TCP 172.23.0.3:57284 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57284 PA / Raw
# Ether / IP / TCP 172.23.0.3:57284 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57284 FA
# Ether / IP / TCP 172.23.0.3:57284 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:57284 A
# Ether / IP / TCP 172.23.0.3:41514 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41514 SA
# Ether / IP / TCP 172.23.0.3:41514 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:41514 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41514 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41514 PA / Raw
# Ether / IP / TCP 172.23.0.3:41514 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41514 PA / Raw
# Ether / IP / TCP 172.23.0.3:41514 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41514 FA
# Ether / IP / TCP 172.23.0.3:41514 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41514 A
# Ether / IP / TCP 172.23.0.3:41524 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41524 SA
# Ether / IP / TCP 172.23.0.3:41524 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:41524 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41524 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41524 PA / Raw
# Ether / IP / TCP 172.23.0.3:41524 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41524 PA / Raw
# Ether / IP / TCP 172.23.0.3:41524 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41524 FA
# Ether / IP / TCP 172.23.0.3:41524 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41524 A
# Ether / IP / TCP 172.23.0.3:41526 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41526 SA
# Ether / IP / TCP 172.23.0.3:41526 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:41526 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41526 A
# Ether / IP / TCP 172.23.0.3:41526 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41526 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41526 PA / Raw
# Ether / IP / TCP 172.23.0.3:41526 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41526 PA / Raw
# Ether / IP / TCP 172.23.0.3:41526 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41526 FA
# Ether / IP / TCP 172.23.0.3:41526 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41526 A
# Ether / IP / TCP 172.23.0.3:41528 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41528 SA
# Ether / IP / TCP 172.23.0.3:41528 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:41528 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41528 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41528 PA / Raw
# Ether / IP / TCP 172.23.0.3:41528 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41528 PA / Raw
# Ether / IP / TCP 172.23.0.3:41528 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:41528 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41528 FA
# Ether / IP / TCP 172.23.0.3:41528 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:41532 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41532 SA
# Ether / IP / TCP 172.23.0.3:41532 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:41532 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41532 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41532 PA / Raw
# Ether / IP / TCP 172.23.0.3:41532 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41532 PA / Raw
# Ether / IP / TCP 172.23.0.3:41532 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41532 FA
# Ether / IP / TCP 172.23.0.3:41532 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41532 A
# Ether / IP / TCP 172.23.0.3:41544 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41544 SA
# Ether / IP / TCP 172.23.0.3:41544 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:41544 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41544 A
# Ether / IP / TCP 172.23.0.3:41544 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41544 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41544 PA / Raw
# Ether / IP / TCP 172.23.0.3:41544 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41544 PA / Raw
# Ether / IP / TCP 172.23.0.3:41544 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41544 FA
# Ether / IP / TCP 172.23.0.3:41544 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41544 A
# Ether / IP / TCP 172.23.0.3:41550 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41550 SA
# Ether / IP / TCP 172.23.0.3:41550 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:41550 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41550 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41550 PA / Raw
# Ether / IP / TCP 172.23.0.3:41550 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41550 PA / Raw
# Ether / IP / TCP 172.23.0.3:41550 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41550 FA
# Ether / IP / TCP 172.23.0.3:41550 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41550 A
# Ether / IP / TCP 172.23.0.3:41552 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41552 SA
# Ether / IP / TCP 172.23.0.3:41552 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:41552 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41552 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41552 PA / Raw
# Ether / IP / TCP 172.23.0.3:41552 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41552 PA / Raw
# Ether / IP / TCP 172.23.0.3:41552 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41552 FA
# Ether / IP / TCP 172.23.0.3:41552 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:41552 A
# Ether / IP / TCP 172.23.0.3:35662 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:35662 SA
# Ether / IP / TCP 172.23.0.3:35662 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:35662 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:35662 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:35662 PA / Raw
# Ether / IP / TCP 172.23.0.3:35662 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:35662 PA / Raw
# Ether / IP / TCP 172.23.0.3:35662 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:35662 FA
# Ether / IP / TCP 172.23.0.3:35662 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:35662 A
# Ether / IP / TCP 172.23.0.3:35678 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:35678 SA
# Ether / IP / TCP 172.23.0.3:35678 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:35678 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:35678 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:35678 PA / Raw
# Ether / IP / TCP 172.23.0.3:35678 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:35678 PA / Raw
# Ether / IP / TCP 172.23.0.3:35678 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:35678 FA
# Ether / IP / TCP 172.23.0.3:35678 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:35678 A
# Ether / IP / TCP 172.23.0.3:35680 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:35680 SA
# Ether / IP / TCP 172.23.0.3:35680 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:35680 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:35680 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:35680 PA / Raw
# Ether / IP / TCP 172.23.0.3:35680 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:35680 PA / Raw
# Ether / IP / TCP 172.23.0.3:35680 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:35680 FA
# Ether / IP / TCP 172.23.0.3:35680 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:35680 A
# Ether / IP / TCP 172.23.0.3:42308 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:42308 SA
# Ether / IP / TCP 172.23.0.3:42308 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:42308 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:42308 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:42308 PA / Raw
# Ether / IP / TCP 172.23.0.3:42308 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:42308 PA / Raw
# Ether / IP / TCP 172.23.0.3:42308 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:42308 FA
# Ether / IP / TCP 172.23.0.3:42308 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:42308 A
# Ether / IP / TCP 172.23.0.3:42324 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:42324 SA
# Ether / IP / TCP 172.23.0.3:42324 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:42324 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:42324 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:42324 PA / Raw
# Ether / IP / TCP 172.23.0.3:42324 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:42324 PA / Raw
# Ether / IP / TCP 172.23.0.3:42324 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:42324 FA
# Ether / IP / TCP 172.23.0.3:42324 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:42324 A
# Ether / IP / TCP 172.23.0.3:42340 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:42340 SA
# Ether / IP / TCP 172.23.0.3:42340 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:42340 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:42340 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:42340 PA / Raw
# Ether / IP / TCP 172.23.0.3:42340 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:42340 PA / Raw
# Ether / IP / TCP 172.23.0.3:42340 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:42340 FA
# Ether / IP / TCP 172.23.0.3:42340 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:42340 A
# Ether / IP / TCP 172.23.0.3:59844 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:59844 SA
# Ether / IP / TCP 172.23.0.3:59844 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:59844 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:59844 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:59844 PA / Raw
# Ether / IP / TCP 172.23.0.3:59844 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:59844 PA / Raw
# Ether / IP / TCP 172.23.0.3:59844 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:59844 FA
# Ether / IP / TCP 172.23.0.3:59844 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:59844 A
# Ether / IP / TCP 172.23.0.3:59858 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:59858 SA
# Ether / IP / TCP 172.23.0.3:59858 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:59858 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:59858 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:59858 PA / Raw
# Ether / IP / TCP 172.23.0.3:59858 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:59858 PA / Raw
# Ether / IP / TCP 172.23.0.3:59858 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:59858 FA
# Ether / IP / TCP 172.23.0.3:59858 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:59858 A
# Ether / IP / TCP 172.23.0.3:59874 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:59874 SA
# Ether / IP / TCP 172.23.0.3:59874 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:59874 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:59874 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:59874 PA / Raw
# Ether / IP / TCP 172.23.0.3:59874 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:59874 PA / Raw
# Ether / IP / TCP 172.23.0.3:59874 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:59874 FA
# Ether / IP / TCP 172.23.0.3:59874 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:59874 A
# Ether / IP / TCP 172.23.0.3:59890 > 172.23.0.4:http S
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:59890 SA
# Ether / IP / TCP 172.23.0.3:59890 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.3:59890 > 172.23.0.4:http PA / Raw
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:59890 A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:59890 PA / Raw
# Ether / IP / TCP 172.23.0.3:59890 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:59890 PA / Raw
# Ether / IP / TCP 172.23.0.3:59890 > 172.23.0.4:http A
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:59890 FA
# Ether / IP / TCP 172.23.0.3:59890 > 172.23.0.4:http FA
# Ether / IP / TCP 172.23.0.4:http > 172.23.0.3:59890 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 S
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 SA
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 PA / Raw
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 FA
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 A
# Ether / IP / TCP 172.23.0.4:1337 > 172.23.0.3:44212 FA
# Ether / IP / TCP 172.23.0.3:44212 > 172.23.0.4:1337 A
