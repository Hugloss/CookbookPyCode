# %% [markdown]
# # Analys local dataset

# %%
from collections import Counter
from datasets import load_dataset

# %%
# path to folder
path_dir = '/datasets/typning/images-2025-04-02-224/'

# %% [markdown]
# ### Load dataset

# %%
dataset = load_dataset("imagefolder", data_dir=path_dir)
# Out:
# ...
# Computing checksums:  53%|#####2    | 77704/146969 [00:05<00:04, 15539.98it/s]
# ...
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
# Check out what's inside
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 146969
#     })
#     validation: Dataset({
#         features: ['image', 'label'],
#         num_rows: 126942
#     })
#     test: Dataset({
#         features: ['image', 'label'],
#         num_rows: 48070
#     })
# })

# %% [markdown]
# #### dataset information

# %%
label_column="label"

# Count the number of samples for each label
train_label_counts = Counter(dataset['train'][label_column])
test_label_counts = Counter(dataset['test'][label_column])
val_label_counts = Counter(dataset['validation'][label_column])

# Print the results
train_label_counts
# Out:
# Counter({18: 25129,
#          2: 22794,
#          17: 12946,
#          13: 7762,
#          6: 6981,
#          12: 6799,
#          14: 6229,
#          9: 5776,
#          15: 5284,
#          7: 5221,
#          0: 4687,
#          5: 4683,
#          4: 4080,
#          11: 3959,
#          20: 3891,
#          21: 3739,
#          19: 3470,
#          8: 2999,
#          16: 2850,
#          10: 2824,
#          1: 2527,
#          3: 2339})

# %%
test_label_counts
# Out:
# Counter({2: 8552,
#          18: 7541,
#          17: 3888,
#          6: 2578,
#          13: 2549,
#          9: 2048,
#          14: 1888,
#          15: 1810,
#          7: 1716,
#          5: 1584,
#          0: 1583,
#          4: 1474,
#          12: 1383,
#          20: 1377,
#          11: 1311,
#          21: 1199,
#          19: 1131,
#          8: 989,
#          10: 933,
#          16: 921,
#          1: 829,
#          3: 786})

# %%
val_label_counts
# Out:
# Counter({2: 20817,
#          18: 19343,
#          17: 11129,
#          13: 6568,
#          6: 5968,
#          12: 5491,
#          14: 5392,
#          9: 4811,
#          15: 4658,
#          5: 4645,
#          7: 4619,
#          0: 4249,
#          4: 3667,
#          11: 3651,
#          20: 3563,
#          21: 3189,
#          19: 3164,
#          8: 2672,
#          10: 2513,
#          16: 2490,
#          1: 2239,
#          3: 2104})
