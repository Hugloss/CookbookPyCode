# %% [markdown]
# # Download table recognition dataset
#
# ### Examples
# - https://github.com/C00pe2/table-transformer-finetuning
# - https://figshare.com/articles/dataset/TabRecSet_A_Large_Scale_Dataset_for_End-to-end_Table_Recognition_in_the_Wild/20647788

# %%
#!wget -nc -O dataset/downloaded_file.zip "https://figshare.com/ndownloader/files/40332520"

# %%
#!unzip dataset/downloaded_file.zip -d dataset/extracted_tab_files
