# %% [markdown]
# # Download nlp dataset
#
# ### Examples
# - https://huggingface.co/datasets?sort=trending&search=swedish
# - https://huggingface.co/datasets/Ekgren/swedish_skolprov
# - https://huggingface.co/datasets/PleIAs/Swedish-PD

# %%
from datasets import load_dataset

# %%
ds = load_dataset("Ekgren/swedish_skolprov", "all")

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['test_id', 'section', 'subsection', 'question_id', 'question_resource', 'question', 'option_a', 'option_b', 'option_c', 'option_d', 'option_e', 'system_prompt', 'prompt', 'answer', 'question_points', 'uid'],
#         num_rows: 545
#     })
# })

# %%
ds['train']
# Out:
# Dataset({
#     features: ['test_id', 'section', 'subsection', 'question_id', 'question_resource', 'question', 'option_a', 'option_b', 'option_c', 'option_d', 'option_e', 'system_prompt', 'prompt', 'answer', 'question_points', 'uid'],
#     num_rows: 545
# })
